# %%
import pandas as pd 
wine_data=pd.read_csv("/home/dulangi/Documents/MSc/dummyData/winequality-red.csv")
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# sort the values
wine_data.sort_values("pH", inplace = True) 
wine_data.head(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 151             9.2             0.520         1.00             3.4      0.610
# 544            14.3             0.310         0.74             1.8      0.075
# 614             9.2             0.755         0.18             2.2      0.148
# 440            12.6             0.310         0.72             2.2      0.072
# 1470           10.0             0.690         0.11             1.4      0.084
# 650            10.7             0.430         0.39             2.2      0.106
# 656            10.7             0.430         0.39             2.2      0.106
# 1018            8.0             0.180         0.37             0.9      0.049
# 1017            8.0             0.180         0.37             0.9      0.049
# 1319            9.1             0.760         0.68             1.7      0.414
# 554            15.5             0.645         0.49             4.2      0.095
# ...

# %%
# remove duplicates
wine_data.drop_duplicates(subset ="pH", keep = False, inplace = True) 
wine_data.head(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 151             9.2             0.520         1.00             3.4      0.610
# 544            14.3             0.310         0.74             1.8      0.075
# 614             9.2             0.755         0.18             2.2      0.148
# 1319            9.1             0.760         0.68             1.7      0.414
# 442            15.6             0.685         0.76             3.7      0.100
# 1270            5.0             0.380         0.01             1.6      0.048
# 553             5.0             1.040         0.24             1.6      0.050
# 94              5.0             1.020         0.04             1.4      0.045
# 95              4.7             0.600         0.17             2.3      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 151                  32.0                  69.0  0.99960  2.74       2.00
# ...

# %%
wine_data.plot.bar(y='quality', x='pH')
# Out:
# <AxesSubplot:xlabel='pH'>
