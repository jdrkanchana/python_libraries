# %%
import pandas as pd
football=pd.read_csv("/home/dul/Football_dataset.csv")
football.tail()
# Out:
# /home/dul/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   NaN  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   NaN  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
#         PlayTimeDiff SideofField  ...  yacEPA  Home_WP_pre  Away_WP_pre  \
# 362442           6.0          GB  ...     0.0     0.051901     0.948099
# 362443           9.0          GB  ...     NaN     0.093435     0.906565
# ...

# %%
# if a row value is missing, the isnull() shows true
# if the row has a value and not a missing value, the isnull() shows false
football.isnull().tail()
# Out:
#          Date  GameID  Drive    qtr   down   time  TimeUnder  TimeSecs  \
# 362442  False   False  False  False  False  False      False     False
# 362443  False   False  False  False   True  False      False     False
# 362444  False   False  False  False   True  False      False     False
# 362445  False   False  False  False  False  False      False     False
# 362446  False   False  False  False   True  False      False     False
#
#         PlayTimeDiff  SideofField  ...  yacEPA  Home_WP_pre  Away_WP_pre  \
# 362442         False        False  ...   False        False        False
# 362443         False        False  ...    True        False        False
# 362444         False        False  ...    True        False        False
# 362445         False        False  ...    True        False        False
# 362446         False        False  ...    True        False        False
#
#         Home_WP_post  Away_WP_post  Win_Prob    WPA  airWPA  yacWPA  Season
# ...

# %%
#notnull() is exact opposite of isnull()
# if a row value is missing, the notnull() shows false
# if the row has a value and not a missing value, the notnull() shows true
football.notnull().tail()
# Out:
#         Date  GameID  Drive   qtr   down  time  TimeUnder  TimeSecs  \
# 362442  True    True   True  True   True  True       True      True
# 362443  True    True   True  True  False  True       True      True
# 362444  True    True   True  True  False  True       True      True
# 362445  True    True   True  True   True  True       True      True
# 362446  True    True   True  True  False  True       True      True
#
#         PlayTimeDiff  SideofField  ...  yacEPA  Home_WP_pre  Away_WP_pre  \
# 362442          True         True  ...    True         True         True
# 362443          True         True  ...   False         True         True
# 362444          True         True  ...   False         True         True
# 362445          True         True  ...   False         True         True
# 362446          True         True  ...   False         True         True
#
#         Home_WP_post  Away_WP_post  Win_Prob   WPA  airWPA  yacWPA  Season
# ...

# %%
# the count of the number of missing values in each row
# that is number of total rows having a missing value per each column
football.isnull().sum()
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         54218
#              ...
# Win_Prob     21993
# WPA           4817
# airWPA      220738
# yacWPA      220956
# Season           0
# Length: 102, dtype: int64

# %%
pd.Series([True,False,True])
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
# The true boolean output taken into sum, false boolean output not considering in counting sum
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
football.shape
# Out:
# (362447, 102)

# %%
# using this way we can drop a row ,if any value in the row is missing
football.dropna(how='any').shape
# Out:
# (0, 102)

# %%
# temporary drop from dataset, to permanently remove need to store the new modified dataset in the csv file
football.shape
# Out:
# (362447, 102)

# %%
# drop a row if in that given row for each column the values are missing
football.dropna(how='all').shape
# Out:
# (362447, 102)

# %%
#in this dataset, the row with each column value missing is not there
# say we drop a row for both the considered columns the value is missing
football.dropna(subset=['down','airWPA'], how='all').shape
# Out:
# (308417, 102)

# %%
# for each row a count as per each category 
football['down'].value_counts()
# Out:
# 1.0    123682
# 2.0     92586
# 3.0     59862
# 4.0     32099
# Name: down, dtype: int64

# %%
# still total count not equal to the total number of rows, NaN values excluded
# to include NaN values too
football['down'].value_counts(dropna=False)
# Out:
# 1.0    123682
# 2.0     92586
# 3.0     59862
# NaN     54218
# 4.0     32099
# Name: down, dtype: int64
