# %%
import pandas as pd
netflix_movies=pd.read_csv("/home/dul/netflix_movies.csv")
netflix_movies.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
# To sort the values in the country column
# To see only the country value and index
netflix_movies.country.sort_values()
# Out:
# 532     Argentina
# 6210    Argentina
# 4075    Argentina
# 398     Argentina
# 4422    Argentina
#           ...
# 6170          NaN
# 6195          NaN
# 6199          NaN
# 6228          NaN
# 6231          NaN
# Name: country, Length: 6234, dtype: object

# %%
# Another way to sort the values in the country column
# To see only the country value and index
# To sort in ascending order
netflix_movies['country'].sort_values()
# Out:
# 532     Argentina
# 6210    Argentina
# 4075    Argentina
# 398     Argentina
# 4422    Argentina
#           ...
# 6170          NaN
# 6195          NaN
# 6199          NaN
# 6228          NaN
# 6231          NaN
# Name: country, Length: 6234, dtype: object

# %%
# to view the dataframe as a whole and not only the sorted
netflix_movies.sort_values('country')
# Out:
#        show_id     type                                   title  \
# 532   81105406  TV Show                 Monzón: A Knockout Blow
# 6210  80239700  TV Show                             Psiconautas
# 4075  80156767    Movie                        La Última Fiesta
# 398   80190990    Movie                     Todo Sobre El Asado
# 4422  80142140    Movie                               Daemonium
# ...        ...      ...                                     ...
# 6170  80136456  TV Show                            Age of Glory
# 6195  80136790  TV Show                          Goodnight DJ 1
# 6199  80244228  TV Show                  Beauty and the Bitches
# 6228  80159925  TV Show                                Kikoriki
# 6231  80116008    Movie  Little Baby Bum: Nursery Rhyme Friends
#
#                            director  \
# 532                             NaN
# 6210                            NaN
# 4075  Leandro Mark, Nicolás Silbert
# 398     Mariano Cohn, Gastón Duprat
# ...

# %%
# sort values is a series method
type(netflix_movies['title'].sort_values())
# Out:
# pandas.core.series.Series

# %%
# To sort descending manner
netflix_movies['country'].sort_values(ascending=False)
# Out:
# 4003    West Germany
# 437          Vietnam
# 171          Vietnam
# 4826         Vietnam
# 117          Vietnam
#             ...
# 6170             NaN
# 6195             NaN
# 6199             NaN
# 6228             NaN
# 6231             NaN
# Name: country, Length: 6234, dtype: object

# %%
# when sorting symbools, numbers come before aplhabetic aharacters
netflix_movies.sort_values('title')
# Out:
#        show_id     type                title               director  \
# 5462  81087095    Movie                #Roxy        Michael Kennedy
# 4699  80147908    Movie            #Rucker50  Robert McCullough Jr.
# 2693  81092768    Movie              #Selfie         Cristina Jacob
# 2694  81092766    Movie           #Selfie 69         Cristina Jacob
# 4     80125979    Movie         #realityhigh       Fernando Lebrija
# ...        ...      ...                  ...                    ...
# 6086  80990464  TV Show             忍者ハットリくん                    NaN
# 5281  80136789  TV Show                 海的儿子                    NaN
# 3904  80226338  TV Show                 마녀사냥                    NaN
# 3799  80226357    Movie              반드시 잡는다          Hong-seon Kim
# 355   81011096    Movie  최강전사 미니특공대 : 영웅의 탄생          Young Jun Lee
#
#                                                    cast        country  \
# 5462  Jake Short, Sarah Fisher, Booboo Stewart, Dann...         Canada
# ...

# %%
netflix_movies.country.order()
# the depracated methods not working now
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-83b246c0cde2> in <module>
# ----> 1 netflix_movies.country.order()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
# sort of by two columns
# first sort by country column, then sort by title column
netflix_movies.sort_values(['country','title'])
# Out:
#        show_id     type                             title  \
# 1834  80241044    Movie       27, el club de los malditos
# 4851  80115152    Movie                          Abzurdah
# 3925  80191555    Movie       Agustín Aristarán: Soy Rada
# 4957  81106517  TV Show  Apache: The Life of Carlos Tevez
# 3321  80149575    Movie                   Caida del Cielo
# ...        ...      ...                               ...
# 5973  81100135  TV Show                       Zombie Dumb
# 1434  81170694    Movie                    Zoé: Panoramas
# 2030  80993794  TV Show               แผนร้ายนายเจ้าเล่ห์
# 5281  80136789  TV Show                              海的儿子
# 355   81011096    Movie               최강전사 미니특공대 : 영웅의 탄생
#
#                                    director  \
# 1834                         Nicanor Loreti
# 4851                          Daniela Goggi
# 3925                           Mariano Baez
# 4957                                    NaN
# ...
